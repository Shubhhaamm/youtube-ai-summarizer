# %%
# !pip install youtube_transcript_api
# Out:
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-1.2.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\sb\appdata\local\programs\python\python314\lib\site-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in c:\users\sb\appdata\local\programs\python\python314\lib\site-packages (from youtube_transcript_api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sb\appdata\local\programs\python\python314\lib\site-packages (from requests->youtube_transcript_api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sb\appdata\local\programs\python\python314\lib\site-packages (from requests->youtube_transcript_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sb\appdata\local\programs\python\python314\lib\site-packages (from requests->youtube_transcript_api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sb\appdata\local\programs\python\python314\lib\site-packages (from requests->youtube_transcript_api) (2025.10.5)
# Downloading youtube_transcript_api-1.2.4-py3-none-any.whl (485 kB)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-1.2.4
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import re
import streamlit as st

genai.configure(api_key="AIzaSyAlx9bdhQcgLP-WhFUUDoWqv_urKzFZimM")

model = genai.GenerativeModel("gemini-2.5-flash-lite")


def get_video_id(url):
    pattern = r"(?:v=|\/)([0-9A-Za-z_-]{11}).*"
    match = re.search(pattern, url)
    if match:
        return match.group(1)
    return None

st.set_page_config(page_title="YouTube AI Summarizer", page_icon="🎥")

st.title("🎥 YouTube Transcript Summarizer")
st.write("Generate English summary + Hindi translation using Gemini AI")

url = st.text_input("https://youtu.be/LPZh9BOjkQs")

if st.button("Generate Summary"):

    if not url:
        st.warning("Please enter a YouTube URL.")
    else:
        video_id = get_video_id(url)

        if not video_id:
            st.error("Invalid YouTube URL.")
        else:
            try:
                with st.spinner("Fetching transcript..."):
                    api = YouTubeTranscriptApi()
                    transcript = api.fetch(video_id)

                    text = " ".join([t.text for t in transcript])

                with st.spinner("Generating summary using Gemini..."):

                    prompt = f"""
                    Summarize the following transcript in 8-10 clear bullet points.
                    Then provide the final summary in Hindi.

                    Transcript:
                    {text[:20000]}
                    """

                    response = model.generate_content(prompt)

                st.success("Summary Generated!")

                st.subheader("📌 AI Output")
                st.write(response.text)

            except Exception as e:
                st.error(f"Error: {str(e)}")
# Out:
# 2026-02-12 03:04:05.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 03:04:05.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
